# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

# %%
def splitted(list, chunk_size):
    return [list[i:i + chunk_size] for i in range(0, len(list), chunk_size)]

# %%
url_most_active = 'https://uk.finance.yahoo.com/markets/stocks/most-active/?start={}&count=100'

# %%
page_no = 0

# %%
r_active = requests.get(url_most_active.format(page_no))

# %%
active_soup = BeautifulSoup(r_active.text, 'lxml')

# %%
headers = active_soup.find_all('th')

# %%
titles = []

for i in headers:
    title = i.text.strip() 
    titles.append(title)

df = pd.DataFrame(columns=titles)
print(titles)
# Out:
# ['Symbol', 'Name', '', 'Price', 'Change', 'Change %', 'Volume', 'Avg vol (3m)', 'Market cap', 'P/E ratio (TTM)', '52-wk change %', '52 Wk range']

# %%
rows = active_soup.find_all('td')

# %%
lines = []

for i in rows:
    line = i.text.strip()
    lines.append(line)

print(lines)
# Out:
# ['PREM.L', 'Premier African Minerals Limited', '', '0.0260 +0.0010 (+4.00%)', '+0.0010', '+4.00%', '2.602B', '214.464M', '9.367M', '-', '-88.50%', '', 'TRP.L', 'Tower Resources plc', '', '0.0295 +0.0020 (+7.27%)', '+0.0020', '+7.27%', '1.046B', '523.762M', '8.568M', '-', '66.67%', '', 'ZG28.L', '-', '', '97.25 -3.49 (-3.46%)', '-3.49', '-3.46%', '846.985M', '-', '--', '-', '-', '', 'ZY21.L', '-', '', '100.27 +100.27 (0.00%)', '+100.27', '0.00%', '823.5M', '-', '--', '-', '-', '', 'EME.L', 'Empyrean Energy Plc', '', '0.1050 -0.0350 (-25.00%)', '-0.0350', '-25.00%', '305.19M', '26.48M', '3.57M', '-', '-75.29%', '', 'RRR.L', 'Red Rock Resources Plc', '', '0.0525 -0.0025 (-4.55%)', '-0.0025', '-4.55%', '198.761M', '67.964M', '3.097M', '-', '-27.40%', '', 'SYME.L', 'Supply@ME Capital plc', '', '0.0029 +0.0000 (+1.75%)', '+0.0000', '+1.75%', '186.896M', '215.452M', '2.08M', '-', '-91.89%', '', 'SNDA.L', 'Sunda Energy Plc', '', '0.0675 +0.0050 (+8.00%)', '+0.0050', '+8.00%', '172.369M', '72.373M', '17.22M', '-', '-20.00%', '', 'QED.L', 'Quadrise Plc', '', '4.1250 -1.6950 (-29.12%)', '-1.6950', '-29.12%', '192.174M', '12.437M', '102.706M', '-', '75.53%', '', 'PU20.L', '-', '', '97.06 +0.76 (+0.79%)', '+0.76', '+0.79%', '152.5M', '-', '--', '-', '-', '', 'VRS.L', 'Versarien plc', '', '0.0325 -0.0015 (-4.41%)', '-0.0015', '-4.41%', '141.488M', '61.531M', '1.245M', '-', '-63.74%', '', '0DNH.IL', 'Atos SE', '', '0.0021 -0.0001 (-4.65%)', '-0.0001', '-4.65%', '135.341M', '221.229M', '325,470', '-', '-99.95%', '', 'VAST.L', 'Vast Resources plc', '', '0.1400 +0.0125 (+9.80%)', '+0.0125', '+9.80%', '145.933M', '73.253M', '3.652M', '-', '-79.16%', '', 'DGI.L', 'DG Innovate Plc', '', '0.0200 -0.0025 (-11.11%)', '-0.0025', '-11.11%', '127.979M', '125.813M', '2.962M', '-', '-91.67%', '', 'ZG23.L', '-', '', '97.93 +0.68 (+0.70%)', '+0.68', '+0.70%', '122M', '-', '--', '-', '-', '', 'ZG35.L', '-', '', '97.84 +0.74 (+0.76%)', '+0.74', '+0.76%', '122M', '-', '--', '-', '-', '', 'NTVO.L', 'Nativo Resources plc', '', '0.0021 0.0000 (0.00%)', '0.0000', '0.00%', '120.243M', '410.486M', '1.296M', '-', '-66.67%', '', 'QBT.L', 'Quantum Blockchain Technologies Plc', '', '1.2450 +0.0600 (+5.06%)', '+0.0600', '+5.06%', '98.655M', '25.488M', '16.077M', '-', '15.81%', '', 'MSMN.L', 'Mosman Oil and Gas Limited', '', '0.0260 +0.0005 (+1.96%)', '+0.0005', '+1.96%', '95.747M', '293.731M', '5.08M', '-', '36.84%', '', 'NTOG.L', 'Nostra Terra Oil and Gas Company plc', '', '0.0385 -0.0020 (-4.94%)', '-0.0020', '-4.94%', '94.799M', '104.815M', '1.933M', '-', '-65.49%', '', 'CLON.L', 'Clontarf Energy plc', '', '0.0400 +0.0035 (+9.59%)', '+0.0035', '+9.59%', '94.63M', '73.396M', '2.917M', '-', '-11.11%', '', 'CPX.L', 'CAP-XX Limited', '', '0.1375 -0.0025 (-1.79%)', '-0.0025', '-1.79%', '93.089M', '185.671M', '8.011M', '-', '-85.08%', '', 'GUN.L', 'Gunsynd Plc', '', '0.1100 0.0000 (0.00%)', '0.0000', '0.00%', '85.64M', '3.649M', '1.042M', '-', '-33.33%', '', 'CTAI.L', 'Catenai PLC', '', '0.2550 +0.0650 (+34.21%)', '+0.0650', '+34.21%', '78.978M', '11.564M', '1.006M', '-', '-53.64%', '', 'GWMO.L', 'Great Western Mining Corporation PLC', '', '0.0195 0.0000 (0.00%)', '0.0000', '0.00%', '77.353M', '57.238M', '2.035M', '-', '-60.00%', '']

# %%
df.head()
# Out:
# Empty DataFrame
# Columns: [Symbol, Name, , Price, Change, Change %, Volume, Avg vol (3m), Market cap, P/E ratio (TTM), 52-wk change %, 52 Wk range]
# Index: []

# %%
chunks = splitted(lines, 12)
# print(chunks)

for i in chunks:
    df.loc[len(df)] = i

df.head(25)
# Out:
#      Symbol                                  Name                       Price  \
# 0    PREM.L      Premier African Minerals Limited     0.0260 +0.0010 (+4.00%)
# 1     TRP.L                   Tower Resources plc     0.0295 +0.0020 (+7.27%)
# 2    ZG28.L                                     -        97.25 -3.49 (-3.46%)
# 3    ZY21.L                                     -      100.27 +100.27 (0.00%)
# 4     EME.L                   Empyrean Energy Plc    0.1050 -0.0350 (-25.00%)
# 5     RRR.L                Red Rock Resources Plc     0.0525 -0.0025 (-4.55%)
# 6    SYME.L                 Supply@ME Capital plc     0.0029 +0.0000 (+1.75%)
# 7    SNDA.L                      Sunda Energy Plc     0.0675 +0.0050 (+8.00%)
# 8     QED.L                          Quadrise Plc    4.1250 -1.6950 (-29.12%)
# 9    PU20.L                                     -        97.06 +0.76 (+0.79%)
# 10    VRS.L                         Versarien plc     0.0325 -0.0015 (-4.41%)
# 11  0DNH.IL                               Atos SE     0.0021 -0.0001 (-4.65%)
# 12   VAST.L                    Vast Resources plc     0.1400 +0.0125 (+9.80%)
# 13    DGI.L                       DG Innovate Plc    0.0200 -0.0025 (-11.11%)
# 14   ZG23.L                                     -        97.93 +0.68 (+0.70%)
# 15   ZG35.L                                     -        97.84 +0.74 (+0.76%)
# 16   NTVO.L                  Nativo Resources plc       0.0021 0.0000 (0.00%)
# 17    QBT.L   Quantum Blockchain Technologies Plc     1.2450 +0.0600 (+5.06%)
# 18   MSMN.L            Mosman Oil and Gas Limited     0.0260 +0.0005 (+1.96%)
# 19   NTOG.L  Nostra Terra Oil and Gas Company plc     0.0385 -0.0020 (-4.94%)
# 20   CLON.L                   Clontarf Energy plc     0.0400 +0.0035 (+9.59%)
# 21    CPX.L                        CAP-XX Limited     0.1375 -0.0025 (-1.79%)
# 22    GUN.L                           Gunsynd Plc       0.1100 0.0000 (0.00%)
# 23   CTAI.L                           Catenai PLC    0.2550 +0.0650 (+34.21%)
# 24   GWMO.L  Great Western Mining Corporation PLC       0.0195 0.0000 (0.00%)
#
#      Change Change %    Volume Avg vol (3m) Market cap P/E ratio (TTM)  \
# 0   +0.0010   +4.00%    2.602B     214.464M     9.367M               -
# 1   +0.0020   +7.27%    1.046B     523.762M     8.568M               -
# 2     -3.49   -3.46%  846.985M            -         --               -
# 3   +100.27    0.00%    823.5M            -         --               -
# 4   -0.0350  -25.00%   305.19M       26.48M      3.57M               -
# 5   -0.0025   -4.55%  198.761M      67.964M     3.097M               -
# 6   +0.0000   +1.75%  186.896M     215.452M      2.08M               -
# 7   +0.0050   +8.00%  172.369M      72.373M     17.22M               -
# 8   -1.6950  -29.12%  192.174M      12.437M   102.706M               -
# 9     +0.76   +0.79%    152.5M            -         --               -
# 10  -0.0015   -4.41%  141.488M      61.531M     1.245M               -
# 11  -0.0001   -4.65%  135.341M     221.229M    325,470               -
# 12  +0.0125   +9.80%  145.933M      73.253M     3.652M               -
# 13  -0.0025  -11.11%  127.979M     125.813M     2.962M               -
# 14    +0.68   +0.70%      122M            -         --               -
# 15    +0.74   +0.76%      122M            -         --               -
# 16   0.0000    0.00%  120.243M     410.486M     1.296M               -
# 17  +0.0600   +5.06%   98.655M      25.488M    16.077M               -
# 18  +0.0005   +1.96%   95.747M     293.731M      5.08M               -
# 19  -0.0020   -4.94%   94.799M     104.815M     1.933M               -
# 20  +0.0035   +9.59%    94.63M      73.396M     2.917M               -
# 21  -0.0025   -1.79%   93.089M     185.671M     8.011M               -
# 22   0.0000    0.00%    85.64M       3.649M     1.042M               -
# 23  +0.0650  +34.21%   78.978M      11.564M     1.006M               -
# 24   0.0000    0.00%   77.353M      57.238M     2.035M               -
#
#    52-wk change % 52 Wk range
# 0         -88.50%
# 1          66.67%
# 2               -
# 3               -
# 4         -75.29%
# 5         -27.40%
# 6         -91.89%
# 7         -20.00%
# 8          75.53%
# 9               -
# 10        -63.74%
# 11        -99.95%
# 12        -79.16%
# 13        -91.67%
# 14              -
# 15              -
# 16        -66.67%
# 17         15.81%
# 18         36.84%
# 19        -65.49%
# 20        -11.11%
# 21        -85.08%
# 22        -33.33%
# 23        -53.64%
# 24        -60.00%

# %%
for chunk in chunks:
    print(chunk)
    df.loc[len(df)] = chunk
# Out:
# ['PREM.L', 'Premier African Minerals Limited', '', '0.0260 +0.0010 (+4.00%)', '+0.0010', '+4.00%', '2.602B', '214.464M', '9.367M', '-', '-88.50%', '']
# ['TRP.L', 'Tower Resources plc', '', '0.0295 +0.0020 (+7.27%)', '+0.0020', '+7.27%', '1.046B', '523.762M', '8.568M', '-', '66.67%', '']
# ['ZG28.L', '-', '', '97.25 -3.49 (-3.46%)', '-3.49', '-3.46%', '846.985M', '-', '--', '-', '-', '']
# ['ZY21.L', '-', '', '100.27 +100.27 (0.00%)', '+100.27', '0.00%', '823.5M', '-', '--', '-', '-', '']
# ['EME.L', 'Empyrean Energy Plc', '', '0.1050 -0.0350 (-25.00%)', '-0.0350', '-25.00%', '305.19M', '26.48M', '3.57M', '-', '-75.29%', '']
# ['RRR.L', 'Red Rock Resources Plc', '', '0.0525 -0.0025 (-4.55%)', '-0.0025', '-4.55%', '198.761M', '67.964M', '3.097M', '-', '-27.40%', '']
# ['SYME.L', 'Supply@ME Capital plc', '', '0.0029 +0.0000 (+1.75%)', '+0.0000', '+1.75%', '186.896M', '215.452M', '2.08M', '-', '-91.89%', '']
# ['SNDA.L', 'Sunda Energy Plc', '', '0.0675 +0.0050 (+8.00%)', '+0.0050', '+8.00%', '172.369M', '72.373M', '17.22M', '-', '-20.00%', '']
# ['QED.L', 'Quadrise Plc', '', '4.1250 -1.6950 (-29.12%)', '-1.6950', '-29.12%', '192.174M', '12.437M', '102.706M', '-', '75.53%', '']
# ['PU20.L', '-', '', '97.06 +0.76 (+0.79%)', '+0.76', '+0.79%', '152.5M', '-', '--', '-', '-', '']
# ['VRS.L', 'Versarien plc', '', '0.0325 -0.0015 (-4.41%)', '-0.0015', '-4.41%', '141.488M', '61.531M', '1.245M', '-', '-63.74%', '']
# ['0DNH.IL', 'Atos SE', '', '0.0021 -0.0001 (-4.65%)', '-0.0001', '-4.65%', '135.341M', '221.229M', '325,470', '-', '-99.95%', '']
# ['VAST.L', 'Vast Resources plc', '', '0.1400 +0.0125 (+9.80%)', '+0.0125', '+9.80%', '145.933M', '73.253M', '3.652M', '-', '-79.16%', '']
# ['DGI.L', 'DG Innovate Plc', '', '0.0200 -0.0025 (-11.11%)', '-0.0025', '-11.11%', '127.979M', '125.813M', '2.962M', '-', '-91.67%', '']
# ['ZG23.L', '-', '', '97.93 +0.68 (+0.70%)', '+0.68', '+0.70%', '122M', '-', '--', '-', '-', '']
# ['ZG35.L', '-', '', '97.84 +0.74 (+0.76%)', '+0.74', '+0.76%', '122M', '-', '--', '-', '-', '']
# ['NTVO.L', 'Nativo Resources plc', '', '0.0021 0.0000 (0.00%)', '0.0000', '0.00%', '120.243M', '410.486M', '1.296M', '-', '-66.67%', '']
# ['QBT.L', 'Quantum Blockchain Technologies Plc', '', '1.2450 +0.0600 (+5.06%)', '+0.0600', '+5.06%', '98.655M', '25.488M', '16.077M', '-', '15.81%', '']
# ['MSMN.L', 'Mosman Oil and Gas Limited', '', '0.0260 +0.0005 (+1.96%)', '+0.0005', '+1.96%', '95.747M', '293.731M', '5.08M', '-', '36.84%', '']
# ['NTOG.L', 'Nostra Terra Oil and Gas Company plc', '', '0.0385 -0.0020 (-4.94%)', '-0.0020', '-4.94%', '94.799M', '104.815M', '1.933M', '-', '-65.49%', '']
# ['CLON.L', 'Clontarf Energy plc', '', '0.0400 +0.0035 (+9.59%)', '+0.0035', '+9.59%', '94.63M', '73.396M', '2.917M', '-', '-11.11%', '']
# ['CPX.L', 'CAP-XX Limited', '', '0.1375 -0.0025 (-1.79%)', '-0.0025', '-1.79%', '93.089M', '185.671M', '8.011M', '-', '-85.08%', '']
# ['GUN.L', 'Gunsynd Plc', '', '0.1100 0.0000 (0.00%)', '0.0000', '0.00%', '85.64M', '3.649M', '1.042M', '-', '-33.33%', '']
# ['CTAI.L', 'Catenai PLC', '', '0.2550 +0.0650 (+34.21%)', '+0.0650', '+34.21%', '78.978M', '11.564M', '1.006M', '-', '-53.64%', '']
# ['GWMO.L', 'Great Western Mining Corporation PLC', '', '0.0195 0.0000 (0.00%)', '0.0000', '0.00%', '77.353M', '57.238M', '2.035M', '-', '-60.00%', '']
